# %% [markdown]
# # References
# - https://www.earthdatascience.org/courses/earth-analytics-python/using-apis-natural-language-processing-twitter/get-and-use-twitter-data-in-python/
#
# - Mapping Disasters with Social Media
#  By: Femi Adenugba, Sue Moy, and Teng Mao at General Assembly in DSI-8-Boston
#      https://github.com/TengCXXI/Mapping-Disasters-with-Social-Media/blob/master/code/twitter_api_tweet_collection.ipynb

# %%
# !pip install tweepy

# %%
import tweepy
import pandas as pd
import json

# %%
# Load credentials from json file
with open("twitter_credentials.json", "r") as file:
    creds = json.load(file)

# %%
consumer_key= creds['CONSUMER_KEY']
consumer_secret= creds['CONSUMER_SECRET']
access_token= creds['ACCESS_TOKEN']
access_token_secret= creds['ACCESS_SECRET']

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
search_words = '#DSI9PROJECT5TEST'   #Ability to add Whatever "trending" tags are being used.
date_since = "2016-11-01"
result_type = "mixed"
# since_id = "1154109669021036546"      # enter the id_str from the last ID of the tweets you got from the last loop

# %%
tweets = tweepy.Cursor(api.search,
                       q=search_words,
                       #lang="en",                 #In disaster scenarios we wouldn't want to limit searches to one language
                       result_type=result_type,
#                        since_id=since_id         
                      ).items(1000)                #1000 most recent tweets
tweets

# %%
tweets_json = [[
                tweet.user.screen_name, 
                tweet.id_str, 
                tweet.created_at, 
                tweet.coordinates, 
                tweet.place,
                tweet.text, 
                tweet.geo 
                ] for tweet in tweets]

# %%
tweets_df = pd.DataFrame(tweets_json, columns = [ 
                                                'screen_name', 
                                                'id_str', 
                                                'created_at',
                                                'coordinates',
                                                'place', 
                                                'text',
                                                'geo_location'
                                               ])

# %%
tweets_df
# Out:
#      screen_name               id_str          created_at coordinates place  \
# 0   DisasterDSI9  1192515038386556928 2019-11-07 18:51:55        None  None
# 1   DisasterDSI9  1192514890013061120 2019-11-07 18:51:20        None  None
# 2   DisasterDSI9  1192190403027574784 2019-11-06 21:21:56        None  None
# 3   DisasterDSI9  1192190000718372864 2019-11-06 21:20:20        None  None
# 4   DisasterDSI9  1192189060334391298 2019-11-06 21:16:36        None  None
# 5   DisasterDSI9  1192179250956251141 2019-11-06 20:37:37        None  None
# 6   DisasterDSI9  1192178562687799298 2019-11-06 20:34:53        None  None
# 7   DisasterDSI9  1192176789424136192 2019-11-06 20:27:50        None  None
# 8   DisasterDSI9  1192176322547716098 2019-11-06 20:25:59        None  None
# 9   DisasterDSI9  1192133704526835714 2019-11-06 17:36:38        None  None
# 10  DisasterDSI9  1192130225523642368 2019-11-06 17:22:49        None  None
#
#                                                  text geo_location
# 0   rain, flood, broken glass, where are the polic...         None
# 1              this is not relevant #DSI9PROJECT5TEST         None
# 2        Okay now it’s beer o’clock #DSI9PROJECT5TEST         None
# 3                  its beer o'clock #DSI9PROJECT5TEST         None
# 4       Now you know where im dying #DSI9PROJECT5TEST         None
# 5   FLooding dsdas wtf my lkjd cribbo im gonna die...         None
# 6     Ayuda a que mi casa se inunde #DSI9PROJECT5TEST         None
# 7   im dying, my house has been blown away #DSI9PR...         None
# 8           #DSI9PROJECT5TEST https://t.co/0XdPt7FUHM         None
# 9   I hope this shitty storm doesn't cancel my pic...         None
# 10  Damn my street is flooded as a bitch #DSI9PROJ...         None

# %%
tweets_df["text_count"] = [len(tweets_df['text'][s].split()) for s in range(len(tweets_df['text']))]

# %%
tweets_df.to_csv('tweets_demo.csv', index=False)

# %%
pd.read_csv('tweets_demo.csv')
# Out:
#      screen_name               id_str           created_at  coordinates  \
# 0   DisasterDSI9  1192515038386556928  2019-11-07 18:51:55          NaN
# 1   DisasterDSI9  1192514890013061120  2019-11-07 18:51:20          NaN
# 2   DisasterDSI9  1192190403027574784  2019-11-06 21:21:56          NaN
# 3   DisasterDSI9  1192190000718372864  2019-11-06 21:20:20          NaN
# 4   DisasterDSI9  1192189060334391298  2019-11-06 21:16:36          NaN
# 5   DisasterDSI9  1192179250956251141  2019-11-06 20:37:37          NaN
# 6   DisasterDSI9  1192178562687799298  2019-11-06 20:34:53          NaN
# 7   DisasterDSI9  1192176789424136192  2019-11-06 20:27:50          NaN
# 8   DisasterDSI9  1192176322547716098  2019-11-06 20:25:59          NaN
# 9   DisasterDSI9  1192133704526835714  2019-11-06 17:36:38          NaN
# 10  DisasterDSI9  1192130225523642368  2019-11-06 17:22:49          NaN
#
#     place                                               text  geo_location  \
# 0     NaN  rain, flood, broken glass, where are the polic...           NaN
# 1     NaN             this is not relevant #DSI9PROJECT5TEST           NaN
# 2     NaN       Okay now it’s beer o’clock #DSI9PROJECT5TEST           NaN
# 3     NaN                 its beer o'clock #DSI9PROJECT5TEST           NaN
# 4     NaN      Now you know where im dying #DSI9PROJECT5TEST           NaN
# 5     NaN  FLooding dsdas wtf my lkjd cribbo im gonna die...           NaN
# 6     NaN    Ayuda a que mi casa se inunde #DSI9PROJECT5TEST           NaN
# 7     NaN  im dying, my house has been blown away #DSI9PR...           NaN
# 8     NaN          #DSI9PROJECT5TEST https://t.co/0XdPt7FUHM           NaN
# 9     NaN  I hope this shitty storm doesn't cancel my pic...           NaN
# 10    NaN  Damn my street is flooded as a bitch #DSI9PROJ...           NaN
#
#     text_count
# 0            9
# 1            5
# 2            6
# 3            4
# 4            7
# 5           10
# 6            8
# 7            9
# 8            2
# 9           10
# 10           9
